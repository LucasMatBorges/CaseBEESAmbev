# %%
# Import the function from the src module
# %run "/Workspace/Users/lucasmatborges@gmail.com/CaseBEESAmbev/Databricks/src/gold_function"
# Out:
# Warning you are using the ipython `%run` line magic. To use the databricks `%run` cell magic make sure that the magic is at the very start of the cell.

# %%
# 1. Path to Silver table
silver_path = "/mnt/datalake/silver/breweries"


# 2. Load Silver table
df_silver = spark.read.format("delta").load(silver_path)


# 3. Gold Aggregation:
#    Qty of breweries per type and location
df_gold = aggregate_gold(df_silver)
display(df_gold)

# 4. Write Gold table (Delta)
gold_path = "/mnt/datalake/gold/breweries_aggregated"

(
    df_gold.write
        .format("delta")
        .mode("overwrite")      
        .save(gold_path)
)

print("Gold aggregated table successfully written")
print(f"Location: {gold_path}")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>state</th><th>brewery_type</th><th>brewery_count</th><th>last_ingest_date</th></tr></thead><tbody><tr><td>United States</td><td>Oregon</td><td>large</td><td>4</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Indiana</td><td>micro</td><td>3</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Arizona</td><td>micro</td><td>3</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Minnesota</td><td>micro</td><td>3</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Wisconsin</td><td>micro</td><td>2</td><td>2025-11-23</td></tr><tr><td>United States</td><td>California</td><td>micro</td><td>2</td><td>2025-11-23</td></tr><tr><td>United States</td><td>New York</td><td>brewpub</td><td>2</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Oregon</td><td>brewpub</td><td>2</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Texas</td><td>micro</td><td>2</td><td>2025-11-23</td></tr><tr><td>United States</td><td>North Carolina</td><td>brewpub</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Mississippi</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Maryland</td><td>contract</td><td>1</td><td>2025-11-23</td></tr><tr><td>South Africa</td><td>KwaZulu-Natal</td><td>brewpub</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>South Carolina</td><td>brewpub</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Nevada</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>North Carolina</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Massachusetts</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Idaho</td><td>large</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Michigan</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Colorado</td><td>proprietor</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Colorado</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Ohio</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>California</td><td>closed</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Oklahoma</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>Ireland</td><td>Laois</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Delaware</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Pennsylvania</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Virginia</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>California</td><td>large</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Colorado</td><td>large</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Iowa</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Colorado</td><td>brewpub</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Illinois</td><td>micro</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Ohio</td><td>brewpub</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Washington</td><td>closed</td><td>1</td><td>2025-11-23</td></tr><tr><td>United States</td><td>Vermont</td><td>micro</td><td>1</td><td>2025-11-23</td></tr></tbody></table></div>
# Gold aggregated table successfully written
# Location: /mnt/datalake/gold/breweries_aggregated
